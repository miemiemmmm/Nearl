# %%
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

X, y = make_circles(n_samples=1_000, factor=0.3, noise=0.05, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=0)

# print(X,y)
# print(len(y))
import matplotlib.pyplot as plt 
plt.scatter(x=X[:,0], y=X[:,1], c=y)

# %%
from sklearn.decomposition import PCA, KernelPCA

pca = PCA(n_components=2)
kernel_pca = KernelPCA(
    n_components=None, kernel="rbf", gamma=10, fit_inverse_transform=True, alpha=0.1
)



X_test_pca = pca.fit(X_train).transform(X_test)
X_test_kernel_pca = kernel_pca.fit(X_train).transform(X_test)

print(X_test_pca.shape)
# print(X_test_pca)

plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], c=y_test)
# Out:
# (250, 2)

# %%
import nltk

from nltk import cluster
from nltk.cluster import euclidean_distance
from numpy import array

vectors = [array(f) for f in [[3, 3], [1, 2], [4, 2], [4, 0]]]

# initialise the clusterer (will also assign the vectors to clusters)
clusterer = cluster.KMeansClusterer(3, euclidean_distance)
clusterer.cluster(vectors, True)

# classify a new vector
print(clusterer.classify(array([3, 3])))
print(dir(clusterer))

clusterer.likelihood
# Out:
# 0
# ['_Tt', '__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_avoid_empty_clusters', '_centroid', '_cluster_vectorspace', '_distance', '_max_difference', '_means', '_normalise', '_num_means', '_repeats', '_rng', '_should_normalise', '_sum_distances', '_svd_dimensions', 'classification_probdist', 'classify', 'classify_vectorspace', 'cluster', 'cluster_name', 'cluster_names', 'cluster_vectorspace', 'likelihood', 'likelihood_vectorspace', 'means', 'num_clusters', 'vector']
# <bound method VectorSpaceClusterer.likelihood of <KMeansClusterer means=[array([3.5, 2.5]), array([1., 2.]), array([4., 0.])] repeats=1>>

# %%
a="this is a test\nthis is a test\nsecondly"


cluster.kmeans.demo()
# Out:
# k-means trial 0
# iteration
# iteration
# Clustered: [array([2, 1]), array([1, 3]), array([4, 7]), array([6, 7])]
# As: [0, 0, 1, 1]
# Means: [array([1.5, 2. ]), array([5., 7.])]
#
# Clustered: [array([3, 3]), array([1, 2]), array([4, 2]), array([4, 0]), array([2, 3]), array([3, 1])]
# As: [1, 0, 1, 0, 1, 0]
# Means: [array([2.66666667, 1.        ]), array([3.        , 2.66666667])]
#
# classify([3 3]): 1
